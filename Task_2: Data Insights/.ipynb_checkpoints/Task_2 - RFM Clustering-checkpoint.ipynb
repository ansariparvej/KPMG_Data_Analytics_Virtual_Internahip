# %% [markdown]
# ### Submitted By: PARVEJ ALAM M. ANSARI

# %% [markdown]
# # Task 02 - RFM Clustering

# %% [markdown]
# In this notebook, I have performed Exploratory Data Analysis on the datasets given by Sprocket Central Pty Ltd.
#
# **“Market Segmentation: One Size Does Not Fit All.”**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/home/ali/Documents/Forge_Internships/KPMG: Data Analytics/helper/OldCustomerList.csv")
df.head()
# Out:
#    customer_id      first_name  last_name  gender  age         DOB  \
# 0            1         Laraine  Medendorp       1   64  1953-10-12
# 1            2             Eli    Bockman       0   37  1980-12-16
# 2            4          Talbot        NaN       0   56  1961-10-03
# 3            5  Sheila-kathryn     Calton       1   40  1977-05-13
# 4            6            Curr  Duckhouse       0   51  1966-09-16
#
#                address  postcode    country state  ...  \
# 0   060 Morning Avenue      2016  Australia   NSW  ...
# 1  6 Meadow Vale Court      2153  Australia   NSW  ...
# 2   0 Holy Cross Court      4211  Australia   QLD  ...
# 3  17979 Del Mar Point      2448  Australia   NSW  ...
# 4     9 Oakridge Court      3216  Australia   VIC  ...
#
#   past_3_years_bike_related_purchases property_valuation     wealth_segment  \
# 0                                  93                 10      Mass Customer
# 1                                  81                 10      Mass Customer
# 2                                  33                  9      Mass Customer
# 3                                  56                  4  Affluent Customer
# 4                                  35                  9     High Net Worth
#
#    tenure deceased_indicator  owns_car  frequency  monetary  recency  \
# 0      11                  0         1         11   3018.09      8.0
# 1      16                  0         1          3   2226.26    129.0
# 2       7                  0         0          2    220.57    196.0
# 3       8                  0         1          6   2394.94     17.0
# 4      13                  0         1          5   3946.55     65.0
#
#    % approved
# 0       100.0
# 1       100.0
# 2       100.0
# 3       100.0
# 4       100.0
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3995 entries, 0 to 3994
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          3995 non-null   int64
#  1   first_name                           3995 non-null   object
#  2   last_name                            3870 non-null   object
#  3   gender                               3995 non-null   int64
#  4   age                                  3995 non-null   int64
#  5   DOB                                  3908 non-null   object
#  6   address                              3995 non-null   object
#  7   postcode                             3995 non-null   int64
#  8   country                              3995 non-null   object
#  9   state                                3995 non-null   object
#  10  job_title                            3491 non-null   object
#  11  job_industry_category                3340 non-null   object
#  12  past_3_years_bike_related_purchases  3995 non-null   int64
#  13  property_valuation                   3995 non-null   int64
#  14  wealth_segment                       3995 non-null   object
#  15  tenure                               3995 non-null   int64
#  16  deceased_indicator                   3995 non-null   int64
#  17  owns_car                             3995 non-null   int64
#  18  frequency                            3995 non-null   int64
#  19  monetary                             3995 non-null   float64
#  20  recency                              3995 non-null   float64
#  21  % approved                           3995 non-null   float64
# dtypes: float64(3), int64(10), object(9)
# memory usage: 686.8+ KB

# %%
RFM = df.loc[:, ['customer_id', 'frequency', 'monetary', 'recency']].copy()

# %%
scaler=StandardScaler()
scaled=scaler.fit_transform(RFM)

# %%
from sklearn.cluster import KMeans

inertia=[]

for i in np.arange(1,11):
    kmeans=KMeans(n_clusters=i)
    kmeans.fit(scaled)
    inertia.append(kmeans.inertia_)


plt.figure(figsize=(12,8))
plt.plot(inertia, marker="o")

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(scaled)
RFM["clusters"] = (kmeans.labels_+1)

# %%
RFM
# Out:
#       customer_id  frequency  monetary     recency  clusters
# 0               1         11   3018.09    8.000000         3
# 1               2          3   2226.26  129.000000         1
# 2               4          2    220.57  196.000000         1
# 3               5          6   2394.94   17.000000         3
# 4               6          5   3946.55   65.000000         3
# ...           ...        ...       ...         ...       ...
# 3990         3996          0      0.00   63.489246         2
# 3991         3997          0      0.00   63.489246         2
# 3992         3998          0      0.00   63.489246         2
# 3993         3999          0      0.00   63.489246         2
# 3994         4000          0      0.00   63.489246         2
#
# [3995 rows x 5 columns]

# %%
clusters = RFM.loc[:, ['customer_id', 'clusters']].copy()

# %%
df = df.merge(clusters, on='customer_id', how='left')
df.head()
# Out:
#    customer_id      first_name  last_name  gender  age         DOB  \
# 0            1         Laraine  Medendorp       1   64  1953-10-12
# 1            2             Eli    Bockman       0   37  1980-12-16
# 2            4          Talbot        NaN       0   56  1961-10-03
# 3            5  Sheila-kathryn     Calton       1   40  1977-05-13
# 4            6            Curr  Duckhouse       0   51  1966-09-16
#
#                address  postcode    country state  ... property_valuation  \
# 0   060 Morning Avenue      2016  Australia   NSW  ...                 10
# 1  6 Meadow Vale Court      2153  Australia   NSW  ...                 10
# 2   0 Holy Cross Court      4211  Australia   QLD  ...                  9
# 3  17979 Del Mar Point      2448  Australia   NSW  ...                  4
# 4     9 Oakridge Court      3216  Australia   VIC  ...                  9
#
#       wealth_segment  tenure  deceased_indicator owns_car  frequency  \
# 0      Mass Customer      11                   0        1         11
# 1      Mass Customer      16                   0        1          3
# 2      Mass Customer       7                   0        0          2
# 3  Affluent Customer       8                   0        1          6
# 4     High Net Worth      13                   0        1          5
#
#    monetary  recency  % approved  clusters
# 0   3018.09      8.0       100.0         3
# 1   2226.26    129.0       100.0         1
# 2    220.57    196.0       100.0         1
# 3   2394.94     17.0       100.0         3
# 4   3946.55     65.0       100.0         3
#
# [5 rows x 23 columns]

# %%
df1 = df.loc[df['clusters'] == 1].copy()
df2 = df.loc[df['clusters'] == 2].copy()
df3 = df.loc[df['clusters'] == 3].copy()

# %%
df1[['frequency','monetary','recency']].describe()
# Out:
#         frequency     monetary     recency
# count  845.000000   845.000000  845.000000
# mean     3.822485  1936.650402  143.634320
# std      1.508810  1143.776543   58.277791
# min      1.000000     0.000000   25.000000
# 25%      3.000000  1014.070000  100.000000
# 50%      4.000000  1859.170000  135.000000
# 75%      5.000000  2659.570000  174.000000
# max     10.000000  5880.330000  354.000000

# %% [markdown]
# > **Cluster 01** is made up of 863 customers who have a high monetary value, frequent purchase behavior, and relatively high recency scores. This indicates that they are profitable and valuable to the business, but they may not be as engaged or loyal as other customers.

# %%
df2[['frequency','monetary','recency']].describe()
# Out:
#         frequency     monetary     recency
# count  913.000000   913.000000  913.000000
# mean     1.493976   615.716835   55.698824
# std      1.850858   851.645897   22.353848
# min      0.000000     0.000000    1.000000
# 25%      0.000000     0.000000   49.000000
# 50%      0.000000     0.000000   63.489246
# 75%      3.000000  1234.130000   63.489246
# max      7.000000  3533.560000  130.000000

# %% [markdown]
# > **Cluster 02**: consists of 894 customers who have low monetary value, infrequent purchase behavior, and high recency scores. These customers may not be as profitable or valuable to the business compared to other segments.

# %%
df3[['frequency','monetary','recency']].describe()
# Out:
#          frequency      monetary      recency
# count  2237.000000   2237.000000  2237.000000
# mean      6.622262   3761.118972    36.377291
# std       1.986967   1635.037016    28.162698
# min       2.000000    263.540000     1.000000
# 25%       5.000000   2554.490000    13.000000
# 50%       6.000000   3531.570000    30.000000
# 75%       8.000000   4738.750000    54.000000
# max      14.000000  11668.950000   161.000000

# %% [markdown]
# > **Cluster 03**: comprises 2238 customers with high monetary value, frequent purchase behavior, and low recency scores. These customers are likely to be profitable and valuable to the business, and their continued engagement suggests they are loyal to the brand.

# %%
transact = pd.read_csv("/home/ali/Documents/Forge_Internships/KPMG: Data Analytics/helper/Transactions.csv")
transact.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost product_first_sold_date
# 0       71.49          53.62     1970-01-01 11:27:25
# 1     2091.47         388.92     1970-01-01 11:35:01
# 2     1793.43         248.82     1970-01-01 10:06:01
# 3     1198.46         381.10     1970-01-01 10:02:25
# 4     1765.30         709.48     1970-01-01 11:43:46

# %%
transact = transact.merge(clusters, on='customer_id', how='left')
transact.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost product_first_sold_date  clusters
# 0       71.49          53.62     1970-01-01 11:27:25       2.0
# 1     2091.47         388.92     1970-01-01 11:35:01       3.0
# 2     1793.43         248.82     1970-01-01 10:06:01       3.0
# 3     1198.46         381.10     1970-01-01 10:02:25       3.0
# 4     1765.30         709.48     1970-01-01 11:43:46       3.0

# %%
transact1 = transact.loc[transact['clusters'] == 1].copy()
transact2 = transact.loc[transact['clusters'] == 2].copy()
transact3 = transact.loc[transact['clusters'] == 3].copy()

# %% [markdown]
# ### High value customers

# %%
ax = sns.distplot(df3['age']);
ax.set_xlabel('Age')
ax.set_ylabel('Density')
ax.set_title("Age distribution for High Value Customers")
plt.show()

# %%
df3['age'].describe()
# Out:
# count    2237.000000
# mean       39.794367
# std        12.424682
# min        15.000000
# 25%        31.000000
# 50%        40.000000
# 75%        49.000000
# max        86.000000
# Name: age, dtype: float64

# %%
custom_palette = sns.color_palette('pastel', n_colors=3)
ax = sns.countplot(data=df3, x='state', palette=custom_palette)

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2.,
            height,
            '{:.2f}%'.format(height * 100 / len(df3['state'])),
            ha="center")

ax.set_xlabel('State')
ax.set_ylabel('Density')
ax.set_title("States of High Value Customers")
plt.show()

# %%
custom_palette = sns.color_palette('pastel', n_colors=3)
ax = sns.countplot(data=df3, x='gender', palette=custom_palette)

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2.,
            height,
            '{:.2f}%'.format(height * 100 / len(df3['state'])),
            ha="center")

ax.set_xlabel('Gender')
ax.set_ylabel('Density')
ax.set_title("Gender of High Value Customers")
plt.show()

# %%
custom_palette = sns.color_palette('pastel', n_colors=3)
ax = sns.countplot(data=df3, x='job_industry_category', palette=custom_palette)

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2.,
            height,
            '{:.2f}%'.format(height * 100 / len(df3['state'])),
            ha="center")

ax.set_xlabel('Job Industry')
ax.set_ylabel('Density')
ax.set_title("Job Industries of High Value Customers")
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
custom_palette = sns.color_palette('pastel', n_colors=3)
ax = sns.countplot(data=df3, x='wealth_segment', palette=custom_palette)

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2.,
            height,
            '{:.2f}%'.format(height * 100 / len(df3['state'])),
            ha="center")

ax.set_xlabel('Wealth Segment')
ax.set_ylabel('Density')
ax.set_title("Wealth Segments of High Value Customers")
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
custom_palette = sns.color_palette('pastel', n_colors=3)
ax = sns.countplot(data=df3, x='owns_car', palette=custom_palette)

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2.,
            height,
            '{:.2f}%'.format(height * 100 / len(df3['state'])),
            ha="center")

ax.set_xlabel('Owns car')
ax.set_ylabel('Density')
ax.set_title("Car ownership of High Value Customers")
plt.show()

# %%
custom_palette = sns.color_palette('pastel', n_colors=3)
ax = sns.countplot(data=transact3, x='brand', palette=custom_palette)

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2.,
            height,
            '{:.2f}%'.format(height * 100 / len(transact3['brand'])),
            ha="center")

ax.set_xlabel('Brand')
ax.set_ylabel('Density')
ax.set_title("Brands of High Value Customers")
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
transact3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14814 entries, 1 to 19444
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           14814 non-null  int64
#  1   product_id               14814 non-null  int64
#  2   customer_id              14814 non-null  int64
#  3   transaction_date         14814 non-null  object
#  4   online_order             14814 non-null  float64
#  5   order_status             14814 non-null  object
#  6   brand                    14814 non-null  object
#  7   product_line             14814 non-null  object
#  8   product_class            14814 non-null  object
#  9   product_size             14814 non-null  object
#  10  list_price               14814 non-null  float64
#  11  standard_cost            14814 non-null  float64
#  12  product_first_sold_date  14814 non-null  object
#  13  clusters                 14814 non-null  float64
# dtypes: float64(4), int64(3), object(7)
# memory usage: 1.7+ MB

# %%
custom_palette = sns.color_palette('pastel', n_colors=3)
ax = sns.countplot(data=transact3, x='product_line', palette=custom_palette)

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2.,
            height,
            '{:.2f}%'.format(height * 100 / len(transact3['brand'])),
            ha="center")

ax.set_xlabel('Brand')
ax.set_ylabel('Density')
ax.set_title("Brands of High Value Customers")
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
custom_palette = sns.color_palette('pastel', n_colors=3)
ax = sns.countplot(data=transact3, x='online_order', palette=custom_palette)

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2.,
            height,
            '{:.2f}%'.format(height * 100 / len(transact3['brand'])),
            ha="center")

ax.set_xlabel('Online Order')
ax.set_ylabel('Density')
ax.set_title("Online Order of High Value Customers")
plt.show()
